# %%
#This jupyter notebook provides an analysis of the student dropout and academic success dataset.
#The dataset can be acquired from this link: https://archive-beta.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success

# %%
#Import libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##**Data Gathering**

# %%
df = pd.read_csv('student_dropout_data.csv')

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
pd.set_option('display.max_columns', 40)

# %%
pd.set_option('display.max_rows', 40)

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %% [markdown]
# ## **Initial Data Inspection & Cleansing**

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# ...

# %%
df.shape
# Out:
# (4424, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %% [markdown]
# ####**Check for missing data**

# %%
df.isna().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %% [markdown]
# ##**Data Exploration**

# %%
#Summary statistics for numerical values.
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
#Summary statistics for all values.
df.describe(include='all')
# Out:
#         Marital status  Application mode  Application order       Course  \
# count      4424.000000       4424.000000        4424.000000  4424.000000
# unique             NaN               NaN                NaN          NaN
# top                NaN               NaN                NaN          NaN
# freq               NaN               NaN                NaN          NaN
# mean          1.178571         18.669078           1.727848  8856.642631
# std           0.605747         17.484682           1.313793  2063.566416
# min           1.000000          1.000000           0.000000    33.000000
# 25%           1.000000          1.000000           1.000000  9085.000000
# 50%           1.000000         17.000000           1.000000  9238.000000
# 75%           1.000000         39.000000           2.000000  9556.000000
# max           6.000000         57.000000           9.000000  9991.000000
#
#         Daytime/evening attendance\t  Previous qualification  \
# ...

# %% [markdown]
# **Correlation**

# %%
df.corr()
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.264006
# Application order                                    -0.125854
# Course                                                0.046365
# Daytime/evening attendance\t                         -0.274939
# Previous qualification                                0.062529
# Previous qualification (grade)                       -0.022406
# Nacionality                                          -0.008843
# Mother's qualification                                0.193163
# Father's qualification                                0.130353
# Mother's occupation                                   0.034994
# Father's occupation                                   0.031609
# Admission grade                                      -0.004771
# Displaced                                            -0.234886
# ...

# %% [markdown]
# **Plot the heatmap for Correlations**

# %%
sns.set(rc={'figure.figsize':(15,9)})

# %%
plt.figure(figsize=(35,16))
sns.heatmap(df.corr().abs(), annot=True, cmap='RdYlGn')
plt.title('Correlation Heatmap', fontsize=25)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ###**Data Visualization**

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %% [markdown]
# **Categorical Variable**

# %%
df['Target'].value_counts().plot(kind='bar')
plt.title('Target Variable Values')
# Out:
# Text(0.5, 1.0, 'Target Variable Values')

# %% [markdown]
# **Numerical Variables**

# %%
df.boxplot(column ='Curricular units 2nd sem (grade)')

# %%
df.boxplot(column ='Curricular units 2nd sem (approved)')

# %%
df['Scholarship holder'].value_counts().plot(kind='bar')
plt.title('Scholarship holder')
# Out:
# Text(0.5, 1.0, 'Scholarship holder')

# %%
df['Tuition fees up to date'].value_counts().plot(kind='bar')
plt.title('Tuition fees up to date')
# Out:
# Text(0.5, 1.0, 'Tuition fees up to date')

# %%
df['Age at enrollment'].plot(kind='hist')
plt.xlabel('Age at enrollment')
# Out:
# Text(0.5, 0, 'Age at enrollment')

# %% [markdown]
# ##**Data Preprocessing**

# %% [markdown]
# **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Target'] = le.fit_transform(df['Target'])

# %%
le.classes_
# Out:
# array(['Dropout', 'Enrolled', 'Graduate'], dtype=object)

# %%
df['Target']
# Out:
# 0       0
# 1       2
# 2       0
# 3       2
# 4       2
#        ..
# 4419    2
# 4420    0
# 4421    0
# 4422    2
# 4423    2
# Name: Target, Length: 4424, dtype: int64

# %%
df['Target'].value_counts()
# Out:
# 2    2209
# 0    1421
# 1     794
# Name: Target, dtype: int64

# %% [markdown]
# **Shuffle the Dataset**

# %%
from sklearn.utils import shuffle

# %%
df = shuffle(df)

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 3172               1                17                  3    9254
# 3576               1                17                  3    9147
# 2215               1                 1                  2    9773
# 432                1                17                  2    9147
# 528                1                39                  1    9147
# ...              ...               ...                ...     ...
# 3910               1                17                  1    9773
# 646                1                 1                  1    9238
# 4129               1                 1                  1    9500
# 1611               1                16                  5    9085
# 3162               1                 1                  4    9500
#
#       Daytime/evening attendance\t  Previous qualification  \
# 3172                             1                       1
# ...

# %% [markdown]
# **Split into X and y**

# %%
X = df.drop(['Target'], axis = 1)
X
# Out:
#       Marital status  Application mode  Application order  Course  \
# 3172               1                17                  3    9254
# 3576               1                17                  3    9147
# 2215               1                 1                  2    9773
# 432                1                17                  2    9147
# 528                1                39                  1    9147
# ...              ...               ...                ...     ...
# 3910               1                17                  1    9773
# 646                1                 1                  1    9238
# 4129               1                 1                  1    9500
# 1611               1                16                  5    9085
# 3162               1                 1                  4    9500
#
#       Daytime/evening attendance\t  Previous qualification  \
# 3172                             1                       1
# ...

# %%
y = df['Target']
y
# Out:
# 3172    0
# 3576    2
# 2215    1
# 432     2
# 528     0
#        ..
# 3910    1
# 646     1
# 4129    2
# 1611    1
# 3162    2
# Name: Target, Length: 4424, dtype: int64

# %% [markdown]
# **Train and Split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, test_size = .2)

# %% [markdown]
# **Balance Dataset**

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

# %%
print(Counter(y))
# Out:
# Counter({2: 2209, 0: 1421, 1: 794})

# %%
oversample = RandomOverSampler(sampling_strategy='minority')

# %%
X, y = oversample.fit_resample(X,y)

# %%
print(Counter(y))
# Out:
# Counter({2: 2209, 1: 2209, 0: 1421})

# %%
X.shape
# Out:
# (5839, 36)

# %% [markdown]
# **Normalize the Dataset**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_m = MinMaxScaler()

# %%
X = scaler_m.fit_transform(X.values)

# %%
X.shape
# Out:
# (5839, 36)

# %% [markdown]
# ##**Modeling**

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr =  LogisticRegression(fit_intercept=True,
                         intercept_scaling = '1',
                         max_iter = 10000,
                         penalty='l2',
                         class_weight='balanced',
                         solver='saga',
                         C=1.0)

# %%
#Train the model.
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', intercept_scaling='1',
#                    max_iter=10000, solver='saga')

# %%
lr.score(X_test,y_test)

# %%
#Predict the values for y.
y_pred = lr.predict (X_test)

# %% [markdown]
# ##**Evaluation**

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-825092b1db6e> in <module>
# ----> 1 cm = confusion_matrix(y_test,y_pred)
#       2 cm
#
# NameError: name 'confusion_matrix' is not defined

# %%
print(classification_report(y_test,y_pred))

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True , fmt='g', cmap='RdYlGn')
plt.xlabel('Predicted')
plt.ylabel('Truth')
